# %%
from Vectorise import ImageVec
import matplotlib.pyplot as plt
import numpy as np

from ngsolve import *
from ngsolve.webgui import Draw
from netgen.webgui import Draw as DrawGeo
from netgen.geom2d import SplineGeometry
from netgen.occ import *

# %%
fig1 = plt.gcf()
vec = ImageVec('Images/Rectangle.png')
pnts = vec.GetVectorisation(kWidth = 20, blurRadius = 30, numSegments = 60, display = True);

#pnts = (pnts-np.min(pnts))/(np.max(pnts)-np.min(pnts))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
geo = SplineGeometry()
vec.GenerateGeometry(geo, 2)

# %%
geo.SetDomainMaxH(4, 0.01)
ngmesh = geo.GenerateMesh(maxh=0.1)

# %%
geo.SetDomainMaxH(4, 0.01)
ngmesh = geo.GenerateMesh(maxh=0.1)
mesh = Mesh(ngmesh)
Draw(mesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %%
V = VectorH1(mesh,order=3, dirichlet="0|1|2")
Q = H1(mesh,order=2)
X = V*Q

u,p = X.TrialFunction()
v,q = X.TestFunction()

nu = 0.001  # viscosity
stokes = (nu*InnerProduct(grad(u), grad(v))+ \
    div(u)*q+div(v)*p - 1e-10*p*q)*dx

a = BilinearForm(stokes).Assemble()

# nothing here ...
f = LinearForm(X).Assemble()

# gridfunction for the solution
gfu = GridFunction(X)

uin = CoefficientFunction( (1.5*4*x*(0.41-x)/(0.41*0.41), 0) )
#uin = CoefficientFunction( (0.8*1.5*4*x*(0.41-x)/(0.41*0.41)+0.5*1.5*4*y*(0.41-y)/(0.41*0.41), 0) )
gfu.components[0].Set(uin, definedon=mesh.Boundaries("0"))
Draw (gfu.components[0], mesh, "vel");
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…

# %%
inv_stokes = a.mat.Inverse(X.FreeDofs())

res = f.vec - a.mat*gfu.vec
gfu.vec.data += inv_stokes * res

Draw (gfu.components[0], mesh);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…

# %%
tau = 0.0008 # timestep

mstar = BilinearForm(u*v*dx+tau*stokes).Assemble()
inv = mstar.mat.Inverse(X.FreeDofs(), inverse="sparsecholesky")

conv = BilinearForm(X, nonassemble=True)
conv += (Grad(u) * u) * v * dx

t = 0; i = 0
tend = 40
gfut = GridFunction(V, multidim=0)
vel = gfu.components[0]
scene = Draw (gfu.components[0], mesh, min=0, max=1.5, autoscale=False)

with TaskManager():
    while t < tend:
        res = conv.Apply(gfu.vec) + a.mat*gfu.vec
        gfu.vec.data -= tau * inv * res

        t = t + tau; i = i + 1
        if i%10 == 0: scene.Redraw()
        if i%50 == 0: gfut.AddMultiDimComponent(vel.vec)
        print(f"t = {t}", end='\r')
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# t = 14.415199999998544655
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 21
#      18 gfu.vec.data -= tau * inv * res
#      20 t = t + tau; i = i + 1
# ---> 21 if i%10 == 0: scene.Redraw()
#      22 if i%50 == 0: gfut.AddMultiDimComponent(vel.vec)
#      23 print(f"t = {t}", end='\r')
#
# File ~\Software\Coding\Conda\miniconda3\envs\maths\lib\site-packages\webgui_jupyter_widgets\widget.py:81, in BaseWebGuiScene.Redraw(self)
#      79 def Redraw(self):
#      80     self.encoding='binary'
# ---> 81     self.widget.value = self.GetData(set_minmax=False)
#
# File ~\Software\Coding\Conda\miniconda3\envs\maths\lib\site-packages\netgen\webgui.py:49, in WebGLScene.GetData(self, set_minmax)
#      47     for t in inspect.getmro(typ):
#      48         if t in _registered_draw_types:
# ---> 49             d = _registered_draw_types[t](self.obj, self.args, self.kwargs)
#      50             break
#      51 if d is None and hasattr(self.obj, "_webgui_data"):
#
# File ~\Software\Coding\Conda\miniconda3\envs\maths\lib\site-packages\ngsolve\webgui.py:83, in GetData(obj, args, kwargs)
#      81 if 'intpoints' not in kwargs:
#      82     kwargs['intpoints']  = None
# ---> 83 d = BuildRenderData(mesh, cf, order=kwargs['order'], draw_surf=kwargs['draw_surf'], draw_vol=kwargs['draw_vol'], intpoints=kwargs['intpoints'], deformation=kwargs['deformation'], regions=regions, objects=kwargs['objects'], nodal_p1=kwargs['nodal_p1'], settings=kwargs['settings'])
#      85 if isinstance(cf, ngs.GridFunction) and len(cf.vecs)>1:
#      86     # multidim gridfunction - generate data for each component
#      87     gf = ngs.GridFunction(cf.space)
#
# File ~\Software\Coding\Conda\miniconda3\envs\maths\lib\site-packages\ngsolve\webgui.py:309, in BuildRenderData(mesh, func, order, draw_surf, draw_vol, intpoints, deformation, regions, objects, nodal_p1, encoding, settings)
#     307     BezierPnts = np.tensordot(iBvals.NumPy(), pmat, axes=(1,1))
#     308 else:
# --> 309     BezierPnts = np.zeros( (og+1, pmat.shape[0], 4) )
#     310     for i in range(4):
#     311         ngsmat = ngs.Matrix(pmat[:,:,i].transpose())
#
# KeyboardInterrupt:

# %%
Draw (gfut, mesh, interpolate_multidim=True, animate=True);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
